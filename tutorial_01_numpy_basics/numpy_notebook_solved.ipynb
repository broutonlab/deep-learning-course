# %% [markdown]
# NumPy is a library for the Python programming language, adding support for large, multi-dimensional arrays and matrices, along with a large collection of high-level mathematical functions to operate on these arrays.
# [numpy doc](https://numpy.org/doc/stable/index.html)

# %%
# numpy installation
# !pip install numpy

# %%
# the classic alias for numpy is np
import numpy as np

# %% [markdown]
# # Arrays in numpy

# %% [markdown]
# The core functionality of NumPy is its "ndarray", for n-dimensional array, data structure. These arrays are strided views on memory. In contrast to Python's built-in list data structure, these arrays are homogeneously typed: all elements of a single array must be of the same type.

# %%
# classic 1d list in python
arr1d = [1, 2, 3, 4, 5]
arr1d
# Out:
# [1, 2, 3, 4, 5]

# %%
# 1d ndarray in numpy
nparr1d = np.array(arr1d)
nparr1d
# Out:
# array([1, 2, 3, 4, 5])

# %%
# classic 2d list in python
arr2d = [
    [1, 2, 3, 4, 5],
    [10, 20, 30, 40, 50],
    [100, 200, 300, 400, 500]
]
arr2d
# Out:
# [[1, 2, 3, 4, 5], [10, 20, 30, 40, 50], [100, 200, 300, 400, 500]]

# %%
# 2d ndarray in numpy
nparr2d = np.array(arr2d)
nparr2d
# Out:
# array([[  1,   2,   3,   4,   5],
#        [ 10,  20,  30,  40,  50],
#        [100, 200, 300, 400, 500]])

# %%
# classic 3d list in python
arr_nd = [[
    [11, 21, 31, 41, 51],
    [110, 210, 310, 410, 510],
    [1100, 2100, 3100, 4100, 5100]
], [
    [12, 22, 32, 42, 52],
    [120, 220, 320, 420, 520],
    [1200, 2200, 3200, 4200, 5200]
]]
arr_nd
# Out:
# [[[11, 21, 31, 41, 51],
#   [110, 210, 310, 410, 510],
#   [1100, 2100, 3100, 4100, 5100]],
#  [[12, 22, 32, 42, 52],
#   [120, 220, 320, 420, 520],
#   [1200, 2200, 3200, 4200, 5200]]]

# %%
# nd ndarray in numpy
nparr_nd = np.array(arr_nd)
nparr_nd
# Out:
# array([[[  11,   21,   31,   41,   51],
#         [ 110,  210,  310,  410,  510],
#         [1100, 2100, 3100, 4100, 5100]],
#
#        [[  12,   22,   32,   42,   52],
#         [ 120,  220,  320,  420,  520],
#         [1200, 2200, 3200, 4200, 5200]]])

# %%
# generate random array
random_arr = np.random.random((10, 10))
random_arr
# Out:
# array([[0.67483495, 0.2773326 , 0.12756256, 0.76337084, 0.73532867,
#         0.35246851, 0.79151315, 0.93031246, 0.79383893, 0.45767003],
#        [0.30502834, 0.3424462 , 0.88203682, 0.92209864, 0.77136583,
#         0.76619481, 0.74343376, 0.4146513 , 0.22359378, 0.84449719],
#        [0.13749757, 0.1321042 , 0.71042602, 0.15041445, 0.99985264,
#         0.69939523, 0.41676936, 0.27260784, 0.87457154, 0.86955482],
#        [0.78261854, 0.13309652, 0.36988106, 0.60538939, 0.99043773,
#         0.04448669, 0.98345417, 0.08722825, 0.04332566, 0.59553692],
#        [0.61621595, 0.47904788, 0.10669327, 0.31630655, 0.95424917,
#         0.83169813, 0.79275301, 0.35824176, 0.32702349, 0.24644245],
#        [0.55648657, 0.1764302 , 0.73660955, 0.62546696, 0.204664  ,
#         0.9224809 , 0.5713275 , 0.45557716, 0.13414729, 0.92005494],
#        [0.36744821, 0.771449  , 0.26677503, 0.58709786, 0.329937  ,
#         0.98016996, 0.21059324, 0.59054249, 0.37231206, 0.07875253],
#        [0.9435039 , 0.40095916, 0.83744712, 0.04089426, 0.25410262,
#         0.77630289, 0.42516991, 0.69320082, 0.43110469, 0.9842457 ],
#        [0.39482513, 0.56007534, 0.05974833, 0.90231981, 0.87795063,
#         0.31802847, 0.72109288, 0.07224205, 0.71741046, 0.26391363],
#        [0.56356644, 0.93369938, 0.23018781, 0.36730485, 0.20779827,
#         0.68512865, 0.58854163, 0.53360691, 0.45189217, 0.70186981]])

# %% [markdown]
# # Basic operations on arrays

# %%
arr1 = np.array([[1, 1, 1],
                 [2, 2, 2],
                 [3, 3, 3]])
arr2 = np.array([[10, 20, 30],
                 [10, 20, 30],
                 [10, 20, 30]])

# %% [markdown]
# All classical arithmetic operations are performed vector-wise, i.e. for all elements at once

# %%
# Vector addition
arr1 + arr2
# Out:
# array([[11, 21, 31],
#        [12, 22, 32],
#        [13, 23, 33]])

# %%
# Vector subtraction
arr2 - arr1
# Out:
# array([[ 9, 19, 29],
#        [ 8, 18, 28],
#        [ 7, 17, 27]])

# %%
# scalar multiplication of matrices
arr1 * arr2
# Out:
# array([[10, 20, 30],
#        [20, 40, 60],
#        [30, 60, 90]])

# %%
# matrix multiplication of matrices
arr1 @ arr2
# Out:
# array([[ 30,  60,  90],
#        [ 60, 120, 180],
#        [ 90, 180, 270]])

# %% [markdown]
# # Vector operations

# %% [markdown]
# Since vector calculations, they occur tens and hundreds of times faster than conventional calculations. Let's demonstrate this with the example of matrix multiplication

# %%
def my_matrix_mult(X, Y):
    result = np.zeros((X.shape[1], Y.shape[0]))
    for i in range(len(X)):
        # iterate through columns of Y
        for j in range(len(Y[0])):
            # iterate through rows of Y
            for k in range(len(Y)):
                result[i][j] += X[i][k] * Y[k][j]
    return result

# %%
# %timeit my_matrix_mult(np.random.random((1 * 10 ** 2, 1 * 10 ** 2)), np.random.random((1 * 10 ** 2, 1 * 10 ** 2)))
# Out:
# 520 ms ± 45.6 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# To demonstrate the speed, we will use arrays with 10 times the dimension

# %%
# %timeit np.random.random((10 ** 3, 10 ** 3)) @ np.random.random((10 ** 3, 10 ** 3))
# Out:
# 35.2 ms ± 8.4 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# # Let's solve some problems yourself! (1 point)

# %% [markdown]
# As a practice, it is proposed to implement these functions through numpy tools
# To find suitable functions, read the [documentation](https://numpy.org/doc/stable/index.html)

# %%
# calculate the sum in each column of a two-dimensional table
def sum_by_columns(arr):
    result_arr = [0] * len(arr[0])
    for j in range(len(arr[0])):
        for i in range(len(arr)):
            result_arr[j] += arr[i][j]
    return result_arr

# %%
def np_sum_by_columns(arr):
    """write your own function using numpy"""
    ...

# %%
for _ in range(10):
    test_arr = np.random.random((np.random.randint(1, 100), np.random.randint(1, 100)))
    assert all(np_sum_by_columns(test_arr) == sum_by_columns(test_arr))
print("Good job!")

# %%
# transpose the matrix
def transposition(arr):
    result_arr = np.zeros((len(arr[0]), len(arr)))
    for i in range(len(arr)):
        for j in range(len(arr[0])):
            result_arr[j][i] = arr[i][j]
    return result_arr

# %%
def np_transposition(arr):
    """write your own function using numpy"""
    ...

# %%
for _ in range(10):
    test_arr = np.random.random((np.random.randint(1, 100), np.random.randint(1, 100)))
    assert (transposition(test_arr) == np_transposition(test_arr)).all()
print("Nice!")

# %%
# calculating the arithmetic mean
def m_mean(arr):
    m = 0
    for i in arr:
        for j in i:
            m += j
    return m / arr.size

# %%
def np_mean(arr):
    """write your own function using numpy"""
    ...

# %%
for _ in range(10):
    test_arr = np.random.random((np.random.randint(1, 100), np.random.randint(1, 100)))
    assert abs(m_mean(test_arr) - np.mean(test_arr)) < 1e-5
print("Well done!")

# %%
# find unique items
def get_uniq(arr):
    uniq = set()
    for row in arr:
        for elem in row:
            uniq.add(elem)
    return sorted(list(uniq))

# %%
def np_get_uniq(arr):
  """write your own function using numpy"""
    ...

# %%
for _ in range(10):
    test_arr = np.random.randint(1, 50, (np.random.randint(1, 10), np.random.randint(1, 10)))
    assert all(get_uniq(test_arr) == np_get_uniq(test_arr))
print('Task completed')

# %% [markdown]
# # Complete the tasks (1 point)

# %% [markdown]
# Extract all the contiguous 3x3 blocks from a random 10x10 matrix

# %%
from numpy.lib import stride_tricks

# %%
Z = np.random.randint(0,5,(10,10))
n = 3
i = 1 + (Z.shape[0]-3)
j = 1 + (Z.shape[1]-3)
C = stride_tricks.as_strided(Z, shape=(i, j, n, n), strides=Z.strides + Z.strides)
print(C)
# Out:
# [[[[1 2 2]
#    [2 2 3]
#    [2 2 3]]
#
#   [[2 2 2]
#    [2 3 1]
#    [2 3 0]]
#
#   [[2 2 2]
#    [3 1 4]
#    [3 0 3]]
#
#   [[2 2 4]
#    [1 4 0]
#    [0 3 0]]
#
#   [[2 4 4]
#    [4 0 3]
#    [3 0 1]]
#
#   [[4 4 1]
#    [0 3 3]
#    [0 1 0]]
#
#   [[4 1 1]
#    [3 3 3]
#    [1 0 3]]
#
#   [[1 1 4]
#    [3 3 4]
#    [0 3 4]]]
#
#
#  [[[2 2 3]
#    [2 2 3]
#    [0 1 1]]
#
#   [[2 3 1]
#    [2 3 0]
#    [1 1 3]]
#
#   [[3 1 4]
#    [3 0 3]
#    [1 3 3]]
#
#   [[1 4 0]
#    [0 3 0]
#    [3 3 2]]
#
#   [[4 0 3]
#    [3 0 1]
#    [3 2 0]]
#
#   [[0 3 3]
#    [0 1 0]
#    [2 0 0]]
#
#   [[3 3 3]
#    [1 0 3]
#    [0 0 3]]
#
#   [[3 3 4]
#    [0 3 4]
#    [0 3 0]]]
#
#
#  [[[2 2 3]
#    [0 1 1]
#    [4 2 4]]
#
#   [[2 3 0]
#    [1 1 3]
#    [2 4 1]]
#
#   [[3 0 3]
#    [1 3 3]
#    [4 1 3]]
#
#   [[0 3 0]
#    [3 3 2]
#    [1 3 4]]
#
#   [[3 0 1]
#    [3 2 0]
#    [3 4 1]]
#
#   [[0 1 0]
#    [2 0 0]
#    [4 1 0]]
#
#   [[1 0 3]
#    [0 0 3]
#    [1 0 1]]
#
#   [[0 3 4]
#    [0 3 0]
#    [0 1 3]]]
#
#
#  [[[0 1 1]
#    [4 2 4]
#    [3 3 2]]
#
#   [[1 1 3]
#    [2 4 1]
#    [3 2 3]]
#
#   [[1 3 3]
#    [4 1 3]
#    [2 3 2]]
#
#   [[3 3 2]
#    [1 3 4]
#    [3 2 1]]
#
#   [[3 2 0]
#    [3 4 1]
#    [2 1 1]]
#
#   [[2 0 0]
#    [4 1 0]
#    [1 1 3]]
#
#   [[0 0 3]
#    [1 0 1]
#    [1 3 4]]
#
#   [[0 3 0]
#    [0 1 3]
#    [3 4 0]]]
#
#
#  [[[4 2 4]
#    [3 3 2]
#    [4 2 4]]
#
#   [[2 4 1]
#    [3 2 3]
#    [2 4 0]]
#
#   [[4 1 3]
#    [2 3 2]
#    [4 0 3]]
#
#   [[1 3 4]
#    [3 2 1]
#    [0 3 2]]
#
#   [[3 4 1]
#    [2 1 1]
#    [3 2 4]]
#
#   [[4 1 0]
#    [1 1 3]
#    [2 4 1]]
#
#   [[1 0 1]
#    [1 3 4]
#    [4 1 3]]
#
#   [[0 1 3]
#    [3 4 0]
#    [1 3 2]]]
#
#
#  [[[3 3 2]
#    [4 2 4]
#    [4 3 2]]
#
#   [[3 2 3]
#    [2 4 0]
#    [3 2 4]]
#
#   [[2 3 2]
#    [4 0 3]
#    [2 4 1]]
#
#   [[3 2 1]
#    [0 3 2]
#    [4 1 1]]
#
#   [[2 1 1]
#    [3 2 4]
#    [1 1 3]]
#
#   [[1 1 3]
#    [2 4 1]
#    [1 3 1]]
#
#   [[1 3 4]
#    [4 1 3]
#    [3 1 0]]
#
#   [[3 4 0]
#    [1 3 2]
#    [1 0 4]]]
#
#
#  [[[4 2 4]
#    [4 3 2]
#    [4 2 1]]
#
#   [[2 4 0]
#    [3 2 4]
#    [2 1 2]]
#
#   [[4 0 3]
#    [2 4 1]
#    [1 2 3]]
#
#   [[0 3 2]
#    [4 1 1]
#    [2 3 3]]
#
#   [[3 2 4]
#    [1 1 3]
#    [3 3 0]]
#
#   [[2 4 1]
#    [1 3 1]
#    [3 0 3]]
#
#   [[4 1 3]
#    [3 1 0]
#    [0 3 2]]
#
#   [[1 3 2]
#    [1 0 4]
#    [3 2 2]]]
#
#
#  [[[4 3 2]
#    [4 2 1]
#    [0 2 4]]
#
#   [[3 2 4]
#    [2 1 2]
#    [2 4 2]]
#
#   [[2 4 1]
#    [1 2 3]
#    [4 2 3]]
#
#   [[4 1 1]
#    [2 3 3]
#    [2 3 4]]
#
#   [[1 1 3]
#    [3 3 0]
#    [3 4 0]]
#
#   [[1 3 1]
#    [3 0 3]
#    [4 0 4]]
#
#   [[3 1 0]
#    [0 3 2]
#    [0 4 1]]
#
#   [[1 0 4]
#    [3 2 2]
#    [4 1 1]]]]

# %% [markdown]
# Considering a 10x3 matrix, extract rows with unequal values (e.g. [2,2,3])

# %%
X = np.random.randint(0,5,(10,3))

# %%
U = X[X.max(axis=1) != X.min(axis=1),:]

# %% [markdown]
# Consider a large vector X, compute X to the power of 3 using 3 different methods

# %%
X = np.random.random(100)

# %%
np.einsum('i,i,i->i',X,X,X)
# Out:
# array([2.38198503e-03, 7.04958167e-04, 1.72930584e-01, 1.75516633e-01,
#        2.06351574e-01, 3.40427965e-02, 3.45454374e-01, 1.79328334e-03,
#        3.41297986e-02, 2.12299289e-03, 2.42402495e-05, 3.39117465e-01,
#        9.16286820e-01, 8.57390432e-10, 2.43974827e-01, 1.42713279e-01,
#        2.96154980e-01, 6.70353384e-01, 2.09330749e-01, 2.98597837e-01,
#        1.88489455e-01, 4.21653997e-01, 3.97433059e-01, 2.95590359e-03,
#        5.03828048e-02, 2.83561783e-02, 3.48848109e-02, 1.89032048e-01,
#        6.38691673e-01, 1.37169935e-02, 5.30996887e-01, 4.55584454e-01,
#        4.84312944e-01, 1.24942992e-01, 3.78162794e-04, 8.35476225e-01,
#        2.03917777e-01, 8.43698570e-03, 4.85596903e-01, 3.38025976e-01,
#        3.50443871e-01, 1.99367233e-01, 5.50743290e-02, 4.08925781e-02,
#        6.11445342e-02, 5.12851564e-03, 5.02448616e-01, 5.48837770e-03,
#        8.90575542e-02, 6.23099880e-05, 2.04478781e-01, 1.18955597e-02,
#        8.82083766e-02, 4.45191818e-01, 4.71092980e-03, 5.10081828e-01,
#        3.27538095e-01, 8.58395242e-01, 2.53226626e-01, 4.37997988e-02,
#        3.78865981e-01, 5.00201041e-02, 2.52624789e-01, 1.67769624e-01,
#        6.11609387e-03, 1.13590548e-01, 2.35395836e-03, 2.68931599e-02,
#        2.04246347e-02, 5.02988201e-01, 1.41741164e-02, 3.14757434e-01,
#        1.22398761e-01, 1.37151013e-02, 4.73242733e-01, 5.48605647e-01,
#        5.84190269e-01, 5.14354691e-02, 8.35563963e-01, 3.50897774e-02,
#        6.96483509e-01, 1.02151744e-05, 3.00404691e-02, 7.08250705e-01,
#        4.75897257e-01, 5.92868502e-01, 8.56630008e-02, 3.69224300e-03,
#        8.48815421e-01, 1.63405274e-01, 1.82653690e-01, 4.79217818e-03,
#        8.39042775e-01, 2.64985750e-02, 9.47371432e-02, 2.54698412e-01,
#        3.65508238e-01, 7.94510419e-03, 2.05720381e-02, 5.39093644e-03])

# %%
np.power(X,3)
# Out:
# array([2.38198503e-03, 7.04958167e-04, 1.72930584e-01, 1.75516633e-01,
#        2.06351574e-01, 3.40427965e-02, 3.45454374e-01, 1.79328334e-03,
#        3.41297986e-02, 2.12299289e-03, 2.42402495e-05, 3.39117465e-01,
#        9.16286820e-01, 8.57390432e-10, 2.43974827e-01, 1.42713279e-01,
#        2.96154980e-01, 6.70353384e-01, 2.09330749e-01, 2.98597837e-01,
#        1.88489455e-01, 4.21653997e-01, 3.97433059e-01, 2.95590359e-03,
#        5.03828048e-02, 2.83561783e-02, 3.48848109e-02, 1.89032048e-01,
#        6.38691673e-01, 1.37169935e-02, 5.30996887e-01, 4.55584454e-01,
#        4.84312944e-01, 1.24942992e-01, 3.78162794e-04, 8.35476225e-01,
#        2.03917777e-01, 8.43698570e-03, 4.85596903e-01, 3.38025976e-01,
#        3.50443871e-01, 1.99367233e-01, 5.50743290e-02, 4.08925781e-02,
#        6.11445342e-02, 5.12851564e-03, 5.02448616e-01, 5.48837770e-03,
#        8.90575542e-02, 6.23099880e-05, 2.04478781e-01, 1.18955597e-02,
#        8.82083766e-02, 4.45191818e-01, 4.71092980e-03, 5.10081828e-01,
#        3.27538095e-01, 8.58395242e-01, 2.53226626e-01, 4.37997988e-02,
#        3.78865981e-01, 5.00201041e-02, 2.52624789e-01, 1.67769624e-01,
#        6.11609387e-03, 1.13590548e-01, 2.35395836e-03, 2.68931599e-02,
#        2.04246347e-02, 5.02988201e-01, 1.41741164e-02, 3.14757434e-01,
#        1.22398761e-01, 1.37151013e-02, 4.73242733e-01, 5.48605647e-01,
#        5.84190269e-01, 5.14354691e-02, 8.35563963e-01, 3.50897774e-02,
#        6.96483509e-01, 1.02151744e-05, 3.00404691e-02, 7.08250705e-01,
#        4.75897257e-01, 5.92868502e-01, 8.56630008e-02, 3.69224300e-03,
#        8.48815421e-01, 1.63405274e-01, 1.82653690e-01, 4.79217818e-03,
#        8.39042775e-01, 2.64985750e-02, 9.47371432e-02, 2.54698412e-01,
#        3.65508238e-01, 7.94510419e-03, 2.05720381e-02, 5.39093644e-03])

# %%
X*X*X
# Out:
# array([2.38198503e-03, 7.04958167e-04, 1.72930584e-01, 1.75516633e-01,
#        2.06351574e-01, 3.40427965e-02, 3.45454374e-01, 1.79328334e-03,
#        3.41297986e-02, 2.12299289e-03, 2.42402495e-05, 3.39117465e-01,
#        9.16286820e-01, 8.57390432e-10, 2.43974827e-01, 1.42713279e-01,
#        2.96154980e-01, 6.70353384e-01, 2.09330749e-01, 2.98597837e-01,
#        1.88489455e-01, 4.21653997e-01, 3.97433059e-01, 2.95590359e-03,
#        5.03828048e-02, 2.83561783e-02, 3.48848109e-02, 1.89032048e-01,
#        6.38691673e-01, 1.37169935e-02, 5.30996887e-01, 4.55584454e-01,
#        4.84312944e-01, 1.24942992e-01, 3.78162794e-04, 8.35476225e-01,
#        2.03917777e-01, 8.43698570e-03, 4.85596903e-01, 3.38025976e-01,
#        3.50443871e-01, 1.99367233e-01, 5.50743290e-02, 4.08925781e-02,
#        6.11445342e-02, 5.12851564e-03, 5.02448616e-01, 5.48837770e-03,
#        8.90575542e-02, 6.23099880e-05, 2.04478781e-01, 1.18955597e-02,
#        8.82083766e-02, 4.45191818e-01, 4.71092980e-03, 5.10081828e-01,
#        3.27538095e-01, 8.58395242e-01, 2.53226626e-01, 4.37997988e-02,
#        3.78865981e-01, 5.00201041e-02, 2.52624789e-01, 1.67769624e-01,
#        6.11609387e-03, 1.13590548e-01, 2.35395836e-03, 2.68931599e-02,
#        2.04246347e-02, 5.02988201e-01, 1.41741164e-02, 3.14757434e-01,
#        1.22398761e-01, 1.37151013e-02, 4.73242733e-01, 5.48605647e-01,
#        5.84190269e-01, 5.14354691e-02, 8.35563963e-01, 3.50897774e-02,
#        6.96483509e-01, 1.02151744e-05, 3.00404691e-02, 7.08250705e-01,
#        4.75897257e-01, 5.92868502e-01, 8.56630008e-02, 3.69224300e-03,
#        8.48815421e-01, 1.63405274e-01, 1.82653690e-01, 4.79217818e-03,
#        8.39042775e-01, 2.64985750e-02, 9.47371432e-02, 2.54698412e-01,
#        3.65508238e-01, 7.94510419e-03, 2.05720381e-02, 5.39093644e-03])

# %% [markdown]
# # Make your own clustering algorithm using numpy (2 points)

# %% [markdown]
# Machine learning is one domain that can frequently take advantage of vectorization and broadcasting. Let’s say that you have the vertices of a triangle (each row is an x, y coordinate)

# %%
# ....
# add picture

# %%
import matplotlib.pyplot as plt

# %%
tri = [[1, 1], [3, 1], [2, 3]]  # create an arbitrary triangle for demonstration

# %%
def find_centroid(arr):
    result_arr = [0] * len(arr[0])
    for row in arr:
        for j, elem in enumerate(row):
            result_arr[j] += elem
    for i, elem in enumerate(result_arr):
        result_arr[i] /= len(arr)
    return result_arr

# %% [markdown]
# The centroid of this “cluster” is an (x, y) coordinate that is the arithmetic mean of each column:

# %%
centroid = find_centroid(tri)  # find the centroid

# %% [markdown]
# It’s helpful to visualize this:

# %%
trishape = plt.Polygon(tri, edgecolor='r', alpha=0.2, lw=5)
_, ax = plt.subplots(figsize=(4, 4))
ax.add_patch(trishape)
ax.set_ylim([.5, 3.5])
ax.set_xlim([.5, 3.5])
ax.scatter(*centroid, color='g', marker='D', s=70)
ax.scatter(*transposition(tri), color='b', s=70)

# %%
# The distance from each vertex of the triangle to the vertex of the triangle
[euclidean_dist(tri[i], centroid) for i in range(len(tri))]
# Out:
# [1.2018504251546631, 1.2018504251546631, 1.3333333333333333]

# %%
# the function of finding the distance between two points in the Euclidean metric
euclidean_dist = lambda point1, point2: sum([(point1[i] - point2[i]) ** 2 for i in range(len(point1))]) ** 0.5

# %% [markdown]
# Finally, let’s take this one step further: let’s say that you have a 2d array X and a 2d array of multiple (x, y) “proposed” centroids. Algorithms such as K-Means clustering work by randomly assigning initial “proposed” centroids, then reassigning each data point to its closest centroid. From there, new centroids are computed, with the algorithm converging on a solution once the re-generated labels (an encoding of the centroids) are unchanged between iterations. A part of this iterative process requires computing the Euclidean distance of each point from each centroid:

# %% [markdown]
# ![picture](https://drive.google.com/uc?export=view&id=1s81eiR8xu_cHuz9JXaKrGO9XVS1N88BF)

# %%
import random

# %%
# Let's create a set of points, which we will then cluster
X = [[3 + random.random() * 4, 3 + random.random() * 4] for _ in range(5)] + [
    [8 + random.random() * 4, 8 + random.random() * 4] for _ in range(5)]

# %%
# let's set the coordinates of the centroid
centroids = [[5, 5], [10, 10]]

# %%
# calculate the distance from each point to each centroid
distances = [[euclidean_dist(x, centroid) for x in X] for centroid in centroids]
distances
# Out:
# [[1.917825596112027,
#   1.7300836668708313,
#   0.6172728377283009,
#   0.4302259562709643,
#   1.8902937020752708,
#   7.042537139726955,
#   5.48155296541448,
#   6.570308374128742,
#   8.341465384749537,
#   8.85678360178068],
#  [6.493469370748211,
#   8.168876440688722,
#   6.63007585629021,
#   7.382632702332483,
#   8.287787465345296,
#   1.0497264226928409,
#   1.8540250682551225,
#   0.6807888209425821,
#   1.3298937450001598,
#   1.7866471323304942]]

# %% [markdown]
# Next, we want the label (index number) of each closest centroid, finding the minimum distance on the 0th axis from the array above:

# %%
# let's determine which of the centroids each point is closer to
labels = [distances[0][i] > distances[1][i] for i in range(len(distances[0]))]

# %% [markdown]
# Let’s inspect this visually, plotting both the two clusters and their assigned labels with a color-mapping

# %%
# Let's display the results
c1, c2 = ['#bc13fe', '#be0119']  # https://xkcd.com/color/rgb/
llim, ulim = 2, 13

_, ax = plt.subplots(figsize=(5, 5))
ax.scatter(*transposition(X), c=np.where(labels, c2, c1), alpha=0.4, s=80)
ax.scatter(*transposition(centroids), c=[c1, c2], marker='s', s=95,
           edgecolor='yellow')
ax.set_ylim([llim, ulim])
ax.set_xlim([llim, ulim])
ax.set_title('One K-Means Iteration: Predicted Classes')
# Out:
# Text(0.5, 1.0, 'One K-Means Iteration: Predicted Classes')

# %% [markdown]
# Plan
#
# 1) Generate a series of points, which will then be clustered
#
# 2) Set the centroid points. In this exercise, they will be known in advance
#
# 3) Calculate the distance from each point to each centroid
#
# 4) For each point, select the centroid with the minimum distance
#
# 5) Display points and centroids colored in the appropriate cluster colors
#
# Good luck!
#
# Below is an implementation without using numpy
#
# More about k-means classification you can read [here](https://en.wikipedia.org/wiki/K-means_clustering)
